# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
obj=Series([1,25,36,23,2.3])
obj
# Out:
# 0     1.0
# 1    25.0
# 2    36.0
# 3    23.0
# 4     2.3
# dtype: float64

# %%
obj[2]
# Out:
# 36.0

# %%
obj2=Series([-2.3,4.6,78,45,0,-3], index= ['a','b','c','d','e','f'])
obj2
# Out:
# a    -2.3
# b     4.6
# c    78.0
# d    45.0
# e     0.0
# f    -3.0
# dtype: float64

# %%
obj2['f']
# Out:
# -3.0
