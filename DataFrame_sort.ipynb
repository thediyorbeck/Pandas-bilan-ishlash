# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
s1.add(s2)
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
s1.apply(np.sqrt)
# Out:
# a    2.701851
# c         NaN
# d    1.843909
# e    1.224745
# dtype: float64

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
np.sqrt(s1)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# a    2.701851
# c         NaN
# d    1.843909
# e    1.224745
# dtype: float64

# %%
# KEling keyingi mashqlar uchun Githubdan kattaroq DF yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.sort_index(axis=1, inplace=True)

# %%
df.sort_values(by='price',ascending=False)
# Out:
#               brand     color      condition country        lot  mileage  \
# 502   mercedes-benz    silver    2 days left     usa  167607883    25302
# 1340           ford  no_color    2 days left     usa  167780682    10536
# 1336           ford  no_color    2 days left     usa  167780680     9643
# 277           dodge      blue  21 hours left     usa  167759490    10944
# 1215           ford     black  21 hours left     usa  167718954     6500
# ...             ...       ...            ...     ...        ...      ...
# 141           dodge    orange    2 days left     usa  167756157   177948
# 391        cadillac     white    9 days left     usa  167651218   105169
# 285            ford     black  17 hours left     usa  167251902   124969
# 290           mazda      gray  16 hours left     usa  167543177   117541
# 354            ford      blue    2 days left     usa  167360535   180364
#
#            model  price      state       title_status                  vin  \
# 502     sl-class  84900    florida      clean vehicle    wddjk7ea3hf044968
# 1340         drw  74000   illinois      clean vehicle    1ft8w4dt6ked32656
# 1336         drw  70000   illinois      clean vehicle    1ft8w3dt3kee48276
# 277   challenger  67000       ohio      clean vehicle    2c3cdzl97kh518237
# 1215         srw  65500    indiana      clean vehicle    1ft7w2bt0kec44818
# ...          ...    ...        ...                ...                  ...
# 141          van      0       utah  salvage insurance    2d8hn44h88r669549
# 391        coupe      0   virginia  salvage insurance    1g6el12y9yu148063
# 285         door      0   oklahoma  salvage insurance    1fafp34p7yw270338
# 290         door      0    indiana  salvage insurance    jm3er293590215768
# 354       pickup      0  tennessee  salvage insurance    1ftyr10d19pa60391
#
#       year
# 502   2017
# 1340  2019
# 1336  2019
# 277   2019
# 1215  2019
# ...    ...
# 141   2008
# 391   2000
# 285   2000
# 290   2009
# 354   2009
#
# [2499 rows x 12 columns]

# %%
df
# Out:
#           brand   color      condition country        lot  mileage    model  \
# 0        toyota   black   10 days left     usa  159348797   274117  cruiser
# 1          ford  silver    6 days left     usa  166951262   190552       se
# 2         dodge  silver    2 days left     usa  167655728    39590      mpv
# 3          ford    blue  22 hours left     usa  167753855    64146     door
# 4     chevrolet     red  22 hours left     usa  167763266     6654     1500
# ...         ...     ...            ...     ...        ...      ...      ...
# 2494     nissan     red    1 days left     usa  167722715    23609    versa
# 2495     nissan  silver  21 hours left     usa  167762225    34553    versa
# 2496     nissan  silver  21 hours left     usa  167762226    31594    versa
# 2497     nissan   black    2 days left     usa  167762227    32557    versa
# 2498     nissan  silver  21 hours left     usa  167762228    31371    versa
#
#       price       state   title_status                  vin  year
# 0      6300  new jersey  clean vehicle    jtezu11f88k007763  2008
# 1      2899   tennessee  clean vehicle    2fmdk3gc4bbb02217  2011
# 2      5350     georgia  clean vehicle    3c4pdcgg5jt346413  2018
# 3     25000    virginia  clean vehicle    1ftfw1et4efc23745  2014
# 4     27700     florida  clean vehicle    3gcpcrec2jg473991  2018
# ...     ...         ...            ...                  ...   ...
# 2494   7800  california  clean vehicle    3n1cn7ap9kl880319  2019
# 2495   9200     florida  clean vehicle    3n1cn7ap5jl884088  2018
# 2496   9200     florida  clean vehicle    3n1cn7ap9jl884191  2018
# 2497   9200     florida  clean vehicle    3n1cn7ap3jl883263  2018
# 2498   9200     florida  clean vehicle    3n1cn7ap4jl884311  2018
#
# [2499 rows x 12 columns]

# %%
df['rating']=df['price'].rank(method='first',ascending=False)
df.sort_values('price', ascending=False)
# Out:
#               brand     color      condition country        lot  mileage  \
# 502   mercedes-benz    silver    2 days left     usa  167607883    25302
# 1340           ford  no_color    2 days left     usa  167780682    10536
# 1336           ford  no_color    2 days left     usa  167780680     9643
# 277           dodge      blue  21 hours left     usa  167759490    10944
# 1215           ford     black  21 hours left     usa  167718954     6500
# ...             ...       ...            ...     ...        ...      ...
# 141           dodge    orange    2 days left     usa  167756157   177948
# 391        cadillac     white    9 days left     usa  167651218   105169
# 285            ford     black  17 hours left     usa  167251902   124969
# 290           mazda      gray  16 hours left     usa  167543177   117541
# 354            ford      blue    2 days left     usa  167360535   180364
#
#            model  price      state       title_status                  vin  \
# 502     sl-class  84900    florida      clean vehicle    wddjk7ea3hf044968
# 1340         drw  74000   illinois      clean vehicle    1ft8w4dt6ked32656
# 1336         drw  70000   illinois      clean vehicle    1ft8w3dt3kee48276
# 277   challenger  67000       ohio      clean vehicle    2c3cdzl97kh518237
# 1215         srw  65500    indiana      clean vehicle    1ft7w2bt0kec44818
# ...          ...    ...        ...                ...                  ...
# 141          van      0       utah  salvage insurance    2d8hn44h88r669549
# 391        coupe      0   virginia  salvage insurance    1g6el12y9yu148063
# 285         door      0   oklahoma  salvage insurance    1fafp34p7yw270338
# 290         door      0    indiana  salvage insurance    jm3er293590215768
# 354       pickup      0  tennessee  salvage insurance    1ftyr10d19pa60391
#
#       year  rating
# 502   2017     1.0
# 1340  2019     2.0
# 1336  2019     3.0
# 277   2019     4.0
# 1215  2019     5.0
# ...    ...     ...
# 141   2008  2457.0
# 391   2000  2483.0
# 285   2000  2460.0
# 290   2009  2461.0
# 354   2009  2479.0
#
# [2499 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         2499 non-null   object
#  1   color         2499 non-null   object
#  2   condition     2499 non-null   object
#  3   country       2499 non-null   object
#  4   lot           2499 non-null   int64
#  5   mileage       2499 non-null   int64
#  6   model         2499 non-null   object
#  7   price         2499 non-null   int64
#  8   state         2499 non-null   object
#  9   title_status  2499 non-null   object
#  10  vin           2499 non-null   object
#  11  year          2499 non-null   int64
#  12  rating        2499 non-null   float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 273.3+ KB

# %%
df.describe()
# Out:
#                 lot       mileage         price         year       rating
# count  2.499000e+03  2.499000e+03   2499.000000  2499.000000  2499.000000
# mean   1.676914e+08  5.229869e+04  18767.671469  2016.714286  1250.000000
# std    2.038772e+05  5.970552e+04  12116.094936     3.442656   721.543484
# min    1.593488e+08  0.000000e+00      0.000000  1973.000000     1.000000
# 25%    1.676253e+08  2.146650e+04  10200.000000  2016.000000   625.500000
# 50%    1.677451e+08  3.536500e+04  16900.000000  2018.000000  1250.000000
# 75%    1.677798e+08  6.347250e+04  25555.500000  2019.000000  1874.500000
# max    1.678055e+08  1.017936e+06  84900.000000  2020.000000  2499.000000

# %%
df['lot'].corr(df['year'])
# Out:
# 0.16458171938751348

# %%
df.corr()
# Out:
# <ipython-input-26-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               lot   mileage     price      year    rating
# lot      1.000000 -0.130475  0.159369  0.164582 -0.174703
# mileage -0.130475  1.000000 -0.400838 -0.594686  0.439442
# price    0.159369 -0.400838  1.000000  0.418274 -0.950048
# year     0.164582 -0.594686  0.418274  1.000000 -0.459620
# rating  -0.174703  0.439442 -0.950048 -0.459620  1.000000

# %%
df.corrwith(df['price'])
# Out:
# <ipython-input-29-4af89057fcc9>:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corrwith(df['price'])
# lot        0.159369
# mileage   -0.400838
# price      1.000000
# year       0.418274
# rating    -0.950048
# dtype: float64

# %%
df
# Out:
#           brand   color      condition country        lot  mileage    model  \
# 0        toyota   black   10 days left     usa  159348797   274117  cruiser
# 1          ford  silver    6 days left     usa  166951262   190552       se
# 2         dodge  silver    2 days left     usa  167655728    39590      mpv
# 3          ford    blue  22 hours left     usa  167753855    64146     door
# 4     chevrolet     red  22 hours left     usa  167763266     6654     1500
# ...         ...     ...            ...     ...        ...      ...      ...
# 2494     nissan     red    1 days left     usa  167722715    23609    versa
# 2495     nissan  silver  21 hours left     usa  167762225    34553    versa
# 2496     nissan  silver  21 hours left     usa  167762226    31594    versa
# 2497     nissan   black    2 days left     usa  167762227    32557    versa
# 2498     nissan  silver  21 hours left     usa  167762228    31371    versa
#
#       price       state   title_status                  vin  year  rating
# 0      6300  new jersey  clean vehicle    jtezu11f88k007763  2008  2118.0
# 1      2899   tennessee  clean vehicle    2fmdk3gc4bbb02217  2011  2344.0
# 2      5350     georgia  clean vehicle    3c4pdcgg5jt346413  2018  2173.0
# 3     25000    virginia  clean vehicle    1ftfw1et4efc23745  2014   659.0
# 4     27700     florida  clean vehicle    3gcpcrec2jg473991  2018   494.0
# ...     ...         ...            ...                  ...   ...     ...
# 2494   7800  california  clean vehicle    3n1cn7ap9kl880319  2019  2025.0
# 2495   9200     florida  clean vehicle    3n1cn7ap5jl884088  2018  1930.0
# 2496   9200     florida  clean vehicle    3n1cn7ap9jl884191  2018  1931.0
# 2497   9200     florida  clean vehicle    3n1cn7ap3jl883263  2018  1932.0
# 2498   9200     florida  clean vehicle    3n1cn7ap4jl884311  2018  1933.0
#
# [2499 rows x 13 columns]

# %%
dodge=df[(df.brand=='dodge') & (df.model=='challenger') & (df['color'].isin(['black','white']))]

# %%
dodge
# Out:
#       brand  color      condition country        lot  mileage       model  \
# 94    dodge  white    2 days left     usa  167755377     3641  challenger
# 819   dodge  white    2 days left     usa  167767030    23783  challenger
# 830   dodge  white    2 days left     usa  167769093     7250  challenger
# 914   dodge  black    8 days left     usa  167553412    27957  challenger
# 916   dodge  white    2 days left     usa  167783956    26292  challenger
# 944   dodge  black    2 days left     usa  167570325    19506  challenger
# 960   dodge  black  21 hours left     usa  167717749    26443  challenger
# 972   dodge  white    2 days left     usa  167792687    22646  challenger
# 986   dodge  black    6 days left     usa  167611462    17154  challenger
# 1001  dodge  black    2 days left     usa  167796319    26428  challenger
# 1005  dodge  black    6 days left     usa  167611476    15446  challenger
# 1012  dodge  white    6 days left     usa  167611479    16679  challenger
# 1015  dodge  black    6 days left     usa  167611481    17870  challenger
# 1070  dodge  black    2 days left     usa  167744650    13906  challenger
# 1131  dodge  white    2 days left     usa  167801949    25825  challenger
# 1133  dodge  white    2 days left     usa  167801953    30585  challenger
# 1177  dodge  black  21 hours left     usa  167752120    13740  challenger
#
#       price           state   title_status                  vin  year  rating
# 94    39800    pennsylvania  clean vehicle    2c3cdzc95fh757310  2015   145.0
# 819   21600      washington  clean vehicle    2c3cdzgg2kh594165  2019   925.0
# 830   43400         arizona  clean vehicle    2c3cdzc99fh713682  2015   116.0
# 914   18900      california  clean vehicle    2c3cdzggxkh532268  2019  1089.0
# 916   38800      california  clean vehicle    2c3cdzc90fh834388  2015   158.0
# 944   20300        virginia  clean vehicle    2c3cdzag1kh656275  2019   993.0
# 960   23800  north carolina  clean vehicle    2c3cdzbt4kh578392  2019   752.0
# 972   19100   west virginia  clean vehicle    2c3cdzag1jh288453  2018  1070.0
# 986   20300    pennsylvania  clean vehicle    2c3cdzgg1kh712965  2019   994.0
# 1001  22700          nevada  clean vehicle    2c3cdzbt4kh642012  2019   853.0
# 1005  19300    pennsylvania  clean vehicle    2c3cdzag2kh679841  2019  1061.0
# 1012  20300    pennsylvania  clean vehicle    2c3cdzgg3kh684649  2019   995.0
# 1015  19300    pennsylvania  clean vehicle    2c3cdzag6kh701727  2019  1062.0
# 1070  18300    pennsylvania  clean vehicle    2c3cdzagxkh687783  2019  1139.0
# 1131  23500  north carolina  clean vehicle    2c3cdzbt5kh578448  2019   771.0
# 1133  21800  north carolina  clean vehicle    2c3cdzbt1kh573652  2019   918.0
# 1177  42500           texas  clean vehicle    2c3cdzc92fh716195  2015   121.0
